    [-64.96242880304257, -68.1384054197882, -64.53196475525054, -68.81406884930936, -59.460448586592776, -70.97341073816929, -71.82550004921467, -67.61641064900991, -72.86269927150636, -72.33589758268454],
    [-64.45639681588428, -70.1185717634484, -64.81989622273339, -69.38113600050556, -56.883710949896056, -71.09367309878938, -68.949757409076, -65.23031063429114, -71.54431098180626, -71.50499076429364],
    [-63.105558970060684, -66.18271110090714, -66.38973604539258, -70.07584542643077, -58.755526430764945, -69.05140776143061, -69.86765450307763, -68.62192008961327, -69.46307694075634, -71.83099275383147],
    [-64.27492896527228, -68.6755022018488, -66.67182104389491, -69.7694204604481, -57.96332487782516, -70.71291667542611, -70.33995280536482, -61.98275646242058, -67.63228285444032, -72.5904394956641],
    [-60.812561660681496, -66.29821177688537, -69.73304598518993, -71.12747454639593, -58.72721068734228, -70.83328362489169, -68.67578989006921, -65.04179062438286, -67.51994180211997, -69.61804794316258]
]

llh3 = list(np.average(np.array(llh3), axis = 0))

# %%
# VNCSMC

llh4 = [-67.57979669018779, -67.85727537956932, -66.40011335970513, -70.04375470220798, -61.154173844127904, -71.3939857595483, -71.90334813309225, -66.09477537953373, -67.71829983729023, -71.90397664100048]

# %%
# resampling by llh_r, not resampling weight matrix, not sampling lambda

# %%
import matplotlib.pyplot as plt

data = [llh_bs, llh_gd, llh1]
names = ["beam", "greedy", "llh1"]
colors = ["red", "green", "blue"]


x = llh_gt 
plt.plot(x, x, color='green', linestyle='-', label='x=y')

for d, n, c in zip(data, names, colors):
    plt.scatter(x, d, color=c, label=n)


# Add labels and legend
plt.xlabel('ground truth')
plt.ylabel('reclustering algos')

plt.legend()

# Display the plot
plt.show()

# %%
data = [llh_bs, llh1, llh2]
names = ["beam", "llh1", "llh2"]
colors = ["red", "green", "blue"]


x = llh_gt 
plt.plot(x, x, color='green', linestyle='-', label='x=y')

for d, n, c in zip(data, names, colors):
    plt.scatter(x, d, color=c, label=n)


# Add labels and legend
plt.xlabel('ground truth')
plt.ylabel('reclustering algos')

plt.legend()

# Display the plot
plt.show()

# %%
data = [llh_bs, llh1, llh3]
names = ["beam","llh1", "llh3"]
colors = ["red", "green", "blue"]


x = llh_gt 
plt.plot(x, x, color='green', linestyle='-', label='x=y')

for d, n, c in zip(data, names, colors):
    plt.scatter(x, d, color=c, label=n)


# Add labels and legend
plt.xlabel('ground truth')
plt.ylabel('reclustering algos')

plt.legend()

# Display the plot
plt.show()

# %%
data = [llh_bs, llh_gd, llh1, llh4]
names = ["beam", "llh1", "llh4"]
colors = ["red", "blue", "thistle"]


x = llh_gt 
plt.plot(x, x, color='green', linestyle='-', label='x=y')

for d, n, c in zip(data, names, colors):
    plt.scatter(x, d, color=c, label=n)


# Add labels and legend
plt.xlabel('ground truth')
plt.ylabel('reclustering algos')

plt.legend()

# Display the plot
plt.show()

# %%
# resambling by current llh, adam. 1000 epochs
llh_a = [-60.25874160994361, -61.01882493537741, -64.77123164876633, -66.24060037006606, -57.20237955885514, -67.87119152945989, -66.91249881790563, -62.307214961393996, -66.4240332465864, -71.40043515763955]

# %%
data = [llh_bs, llh_gd, llh_a]
names = ["beam", "llh1", "VCSMC"]
colors = ["red", "blue", "thistle"]


x = llh_gt 
plt.plot(x, x, color='green', linestyle='-', label='x=y')

for d, n, c in zip(data, names, colors):
    plt.scatter(x, d, color=c, label=n)


# Add labels and legend
plt.xlabel('ground truth')
plt.ylabel('reclustering algos')

plt.legend()

# Display the plot
plt.show()
